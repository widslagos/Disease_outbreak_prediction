# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import xlrd

# %%
com_data = pd.read_excel("Lagos Annual IDSR-003 2009.xls", sheetname= "All Dxes LGAs  Annualized Cummu")
com_data.head()
# Out:
#   Cummulative Monthly State IDSR summary report Unnamed: 1  \
# 0                                           NaN    State:
# 1                                           NaN        NaN
# 2   Yobe State Cummulative  IDSR summary report        NaN
# 3                                           S/N        LGA
# 4                                           NaN        NaN
#
#                 Unnamed: 2 Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0  Month: September , 2008        NaN           NaN        NaN
# 1                      NaN        NaN           NaN        NaN
# 2                      NaN        NaN           NaN        NaN
# 3                    1.CSM        NaN   2.  Cholera        NaN
# 4                        C          D             C          D
#
#                               Unnamed: 6 Unnamed: 7  \
# 0                                    NaN        NaN
# 1                                    NaN        NaN
# 2                                    NaN        NaN
# ...

# %%
com_data2 = pd.read_excel("Lagos Annual IDSR-003 2010.xls", sheetname= "All Dxes LGAs  Annualized Cummu")
com_data2.head()
# Out:
#    Cummulative Monthly State IDSR summary report     Unnamed: 1 Unnamed: 2  \
# 0                                            NaN  State:  Lagos    Month:
# 1                                            NaN            NaN        NaN
# 2  Lagos  State Cummulative  IDSR summary report            NaN        NaN
# 3                                            S/N            LGA      1.CSM
# 4                                            NaN            NaN          C
#
#   Unnamed: 3    Unnamed: 4 Unnamed: 5                             Unnamed: 6  \
# 0        NaN           NaN        NaN                                    NaN
# 1        NaN           NaN        NaN                                    NaN
# 2        NaN           NaN        NaN                                    NaN
# 3        NaN   2.  Cholera        NaN   3.  Diarrhoea (Watery without blood)
# 4          D             C          D                                      C
#
# ...

# %%
data = pd.read_excel("Lagos Annual IDSR-003 2009.xls")       
data
# Out:
#       ROUTINE MONTHLY NOTIFICATION FORM:  IDSR 003          Unnamed: 1  \
# 0                                       LGA: Agege                 NaN
# 1                                No. of HF/ LGAs:                  NaN
# 2                                              NaN                 NaN
# 3                                          DISEASE  Cases out-patients
# 4                                              NaN      Less than 5yrs
# 5                                         1.   CSM                 NaN
# 6                                     2.   Cholera                 NaN
# 7            3.   Diarrhoea (Watery without blood)                  78
# 8                      4.   Diarrhoea (with blood)                 NaN
# 9                  5.Dracunculiasis\n(Guinea worm)                 NaN
# 10                                6.   Hepatitis B                 NaN
# 11                                   7.   HIV/AIDS                 NaN
# ...

# %%
com_data = pd.io.parsers.read_table("Lagos Annual IDSR-003 2009.xls")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-107310a59d4a> in <module>()
# ----> 1 com_data = pd.io.parsers.read_table("Lagos Annual IDSR-003 2009.xls")
#
# ...
